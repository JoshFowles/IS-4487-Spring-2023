# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshFowles/IS-4487-Spring-2023/blob/main/Module2_Script_v1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Module 2 Script
#
# ## Agenda
#
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# Make sure you have downloaded tonight's script and data from Canvas.

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib
#
# We can pull sample data from
# - statsmodels.api

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive 


df = pd.read_csv (r'/content/drive/MyDrive/Colab Notebooks/megatelco.csv')

print (df)
# Out:
#      college  income  overage  leftover   house  handset_price  \
# 0        one   23859       70         0  519105            154
# 1       zero   72466       67        16  271182            262
# 2       zero   30883       60         0  647281            211
# 3        one   44512        0        22  754958            232
# 4       zero   70535        0         0  653421            310
# ...      ...     ...      ...       ...     ...            ...
# 4995    zero   93699       26        56  385632            384
# 4996    zero   25806       67        87  691020            142
# 4997     one   97033      138        28  710559            311
# 4998    zero   91558      229        15  853464            379
# 4999     one  115943      200        42  173038            459
#
#       over_15mins_calls_per_month  average_call_duration  \
# 0                             5.0                      8
# 1                             5.0                      5
# 2                             3.0                      8
# 3                             0.0                      5
# 4                             0.0                     14
# ...                           ...                    ...
# 4995                          5.0                      1
# 4996                          4.0                      2
# 4997                         10.0                      2
# 4998                         27.0                      4
# 4999                         24.0                      2
#
#      reported_satisfaction reported_usage_level considering_change_of_plan  \
# 0                      low                  low                        yes
# 1                      low                  low                        yes
# 2                      low                  low                        yes
# 3                      low                  low                         no
# 4                      low                  low                        yes
# ...                    ...                  ...                        ...
# 4995                  high                  low                        yes
# 4996                  high                  low                         no
# 4997                   low                 high                        yes
# 4998                  high                  low                         no
# 4999                  high                 high                        yes
#
#       leave     id
# 0     LEAVE   8183
# 1     LEAVE  12501
# 2      STAY   7425
# 3     LEAVE  13488
# 4      STAY  11389
# ...     ...    ...
# 4995  LEAVE  19270
# 4996   STAY  14549
# 4997   STAY   9972
# 4998   STAY  12685
# 4999  LEAVE  13561
#
# [5000 rows x 13 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#look at the top rows
df.head(10)
# Out:
#   college  income  overage  leftover   house  handset_price  \
# 0     one   23859       70         0  519105            154
# 1    zero   72466       67        16  271182            262
# 2    zero   30883       60         0  647281            211
# 3     one   44512        0        22  754958            232
# 4    zero   70535        0         0  653421            310
# 5    zero  143987        0        56  896544            778
# 6     one   96668       79        24  259329            365
# 7     one   50083        0         0  160335            266
# 8     one  104392        0         0  247836            778
# 9     one   37852        0        74  264893            857
#
#    over_15mins_calls_per_month  average_call_duration reported_satisfaction  \
# 0                          5.0                      8                   low
# 1                          5.0                      5                   low
# 2                          3.0                      8                   low
# 3                          0.0                      5                   low
# 4                          0.0                     14                   low
# 5                          5.0                      1                   low
# 6                          5.0                      6                   low
# 7                          5.0                     10                   low
# 8                          1.0                      8                  high
# 9                          0.0                      2                   low
#
#   reported_usage_level considering_change_of_plan  leave     id
# 0                  low                        yes  LEAVE   8183
# 1                  low                        yes  LEAVE  12501
# 2                  low                        yes   STAY   7425
# 3                  low                         no  LEAVE  13488
# 4                  low                        yes   STAY  11389
# 5                 high                        yes   STAY  14674
# 6                  avg                        yes  LEAVE  19100
# 7                 high                        yes   STAY  18170
# 8                  low                         no  LEAVE   3201
# 9                  low                        yes  LEAVE  12612

# %%
#look at last rows
df.tail(10)
# Out:
#      college  income  overage  leftover   house  handset_price  \
# 4990     one  158179      226        21  269368            478
# 4991     one   75711       47         0  519512            326
# 4992     one   34039       59         0  541872            165
# 4993    zero   88713        0        70  587559            319
# 4994    zero  123820        0        71  608639            888
# 4995    zero   93699       26        56  385632            384
# 4996    zero   25806       67        87  691020            142
# 4997     one   97033      138        28  710559            311
# 4998    zero   91558      229        15  853464            379
# 4999     one  115943      200        42  173038            459
#
#       over_15mins_calls_per_month  average_call_duration  \
# 4990                         18.0                      5
# 4991                          4.0                     12
# 4992                          3.0                     10
# 4993                          0.0                      2
# 4994                          1.0                      2
# 4995                          5.0                      1
# 4996                          4.0                      2
# 4997                         10.0                      2
# 4998                         27.0                      4
# 4999                         24.0                      2
#
#      reported_satisfaction reported_usage_level considering_change_of_plan  \
# 4990                   avg                 high                        yes
# 4991                  high                 high                        yes
# 4992                   low                 high                        yes
# 4993                   low                  low                        yes
# 4994                   low                 high                        yes
# 4995                  high                  low                        yes
# 4996                  high                  low                         no
# 4997                   low                 high                        yes
# 4998                  high                  low                         no
# 4999                  high                 high                        yes
#
#       leave     id
# 4990  LEAVE  18481
# 4991   STAY   9790
# 4992   STAY  19985
# 4993  LEAVE  17220
# 4994   STAY  10396
# 4995  LEAVE  19270
# 4996   STAY  14549
# 4997   STAY   9972
# 4998   STAY  12685
# 4999  LEAVE  13561

# %%
#get a summary of the dataset
df.describe()
# Out:
#               income      overage     leftover           house  handset_price  \
# count    5000.000000  5000.000000  5000.000000     5000.000000   5.000000e+03
# mean    79912.948400    85.119200    24.243600   493656.326600   7.876236e+02
# std     41703.042384    85.655622    26.847496   254287.193865   2.828291e+04
# min    -28811.000000     0.000000     0.000000  -796132.000000   1.300000e+02
# 25%     41592.500000     0.000000     0.000000   260586.500000   2.190000e+02
# 50%     75041.500000    59.000000    15.000000   451865.500000   3.220000e+02
# 75%    115475.000000   177.000000    42.000000   701608.750000   5.280000e+02
# max    159938.000000   335.000000    89.000000  1000000.000000   2.000234e+06
#
#        over_15mins_calls_per_month  average_call_duration            id
# count                  4997.000000            5000.000000   5000.000000
# mean                      7.744647               5.958800  10036.639400
# std                       8.806070               4.390417   5813.620304
# min                       0.000000               1.000000      2.000000
# 25%                       1.000000               2.000000   4950.500000
# 50%                       4.000000               5.000000  10126.000000
# 75%                      14.000000               9.000000  15085.250000
# max                      29.000000              15.000000  20000.000000

# %%
#look at the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   college                      5000 non-null   object
#  1   income                       5000 non-null   int64
#  2   overage                      5000 non-null   int64
#  3   leftover                     5000 non-null   int64
#  4   house                        5000 non-null   int64
#  5   handset_price                5000 non-null   int64
#  6   over_15mins_calls_per_month  4997 non-null   float64
#  7   average_call_duration        5000 non-null   int64
#  8   reported_satisfaction        5000 non-null   object
#  9   reported_usage_level         5000 non-null   object
#  10  considering_change_of_plan   5000 non-null   object
#  11  leave                        5000 non-null   object
#  12  id                           5000 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 507.9+ KB

# %% [markdown]
# ## Clean up the data
# Did you notice anything unusual about the "house" amounts?
#
# How about the handset price and income?

# %%
df_clean = df[(df['house'] > 0) & (df['income'] > 0) & (df['handset_price'] < 1000) & (df['handset_price'] > 200) & (df['leftover'] >10)]
df_clean.describe()
# Out:
#               income      overage     leftover          house  handset_price  \
# count    2322.000000  2322.000000  2322.000000    2322.000000    2322.000000
# mean    89702.869078    85.427649    40.807063  498781.327304     442.765289
# std     40027.067462    85.801752    24.374445  258308.670554     204.986261
# min     20201.000000     0.000000    11.000000  150305.000000     201.000000
# 25%     57063.750000     0.000000    19.000000  261860.500000     275.000000
# 50%     89012.000000    60.000000    34.000000  448809.000000     367.000000
# 75%    123931.250000   177.000000    62.000000  718622.750000     601.000000
# max    159938.000000   335.000000    89.000000  999651.000000     899.000000
#
#        over_15mins_calls_per_month  average_call_duration            id
# count                  2320.000000            2322.000000   2322.000000
# mean                      7.796983               3.366494  10021.878122
# std                       8.821437               2.586972   5760.676099
# min                       0.000000               1.000000      2.000000
# 25%                       1.000000               1.000000   5110.250000
# 50%                       4.000000               2.000000  10123.000000
# 75%                      14.000000               5.000000  14963.750000
# max                      29.000000              15.000000  19997.000000

# %% [markdown]
# # Add Derived Attribute
#
# Add a column with the income in K (thousands)

# %%
df_clean['income_k'] = (df_clean['income']/1000).round(2)
df_clean.head()
# Out:
# <ipython-input-14-41bea05a8bf4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['income_k'] = (df_clean['income']/1000).round(2)
#   college  income  overage  leftover   house  handset_price  \
# 1    zero   72466       67        16  271182            262
# 3     one   44512        0        22  754958            232
# 5    zero  143987        0        56  896544            778
# 6     one   96668       79        24  259329            365
# 9     one   37852        0        74  264893            857
#
#    over_15mins_calls_per_month  average_call_duration reported_satisfaction  \
# 1                          5.0                      5                   low
# 3                          0.0                      5                   low
# 5                          5.0                      1                   low
# 6                          5.0                      6                   low
# 9                          0.0                      2                   low
#
#   reported_usage_level considering_change_of_plan  leave     id  income_k
# 1                  low                        yes  LEAVE  12501     72.47
# 3                  low                         no  LEAVE  13488     44.51
# 5                 high                        yes   STAY  14674    143.99
# 6                  avg                        yes  LEAVE  19100     96.67
# 9                  low                        yes  LEAVE  12612     37.85

# %% [markdown]
# ## Slice the data
#  What is average house price at the two levels of leave?
#
#  Conclusion?  Stayers have substantially more expensive homes.

# %%
df_clean[['house','leave']].groupby('leave').mean().round(2)
# Out:
#            house
# leave
# LEAVE  452884.78
# STAY   545314.77

# %% [markdown]
# This is slicing the data. We will now add code to create a chart for the data

# %%
df_clean['leftover'].hist(orientation = "horizontal")

# %%
df_clean.plot.scatter(x = 'income_k', y = 'handset_price')
